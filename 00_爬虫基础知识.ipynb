# %% [markdown]
# # 1 了解HTML语言

# %% [markdown]
# HTML语言的文档结构是树形的。

# %%
html_doc = """
<html><head><title>The Dormouse's story</title></head>
<body>
<p class="title"><b>The Dormouse's story</b></p>

<p class="story">Once upon a time there were three little sisters; and their names were
<a href="http://example.com/elsie" class="sister" id="link1">Elsie</a>,
<a href="http://example.com/lacie" class="sister" id="link2">Lacie</a> and
<a href="http://example.com/tillie" class="sister" id="link3">Tillie</a>;
and they lived at the bottom of a well.</p>

<p class="story">...</p>
"""

# %% [markdown]
# # 2 学习BeautifulSoup和requests

# %%
from bs4 import BeautifulSoup as bs
soup = bs(html_doc, 'html.parser')
print(soup.prettify())
# Out:
# <html>
#  <head>
#   <title>
#    The Dormouse's story
#   </title>
#  </head>
#  <body>
#   <p class="title">
#    <b>
#     The Dormouse's story
#    </b>
#   </p>
#   <p class="story">
#    Once upon a time there were three little sisters; and their names were
#    <a class="sister" href="http://example.com/elsie" id="link1">
#     Elsie
#    </a>
#    ,
#    <a class="sister" href="http://example.com/lacie" id="link2">
#     Lacie
#    </a>
#    and
#    <a class="sister" href="http://example.com/tillie" id="link3">
#     Tillie
#    </a>
#    ;
# and they lived at the bottom of a well.
#   </p>
#   <p class="story">
#    ...
#   </p>
#  </body>
# </html>

# %%
print(soup.title)
print(soup.title.name)
print(soup.title.string)
print(soup.title.parent.name)
print(soup.p)
print(soup.p['class'])
print(soup.a)
# Out:
# <title>The Dormouse's story</title>
# title
# The Dormouse's story
# head
# <p class="title"><b>The Dormouse's story</b></p>
# ['title']
# <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>

# %%
print(soup.find(href="http://example.com/tillie"))
# Out:
# <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>

# %%
print(soup.find_all('a'))
# Out:
# [<a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>, <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a>, <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>]

# %%
import requests

url = "http://www.cufe.edu.cn"
response = requests.get(url)

soup = bs(response.content,"lxml")
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html>
#  <head>
#   <title>
#    中央财经大学
#   </title>
#   <meta content="中央财经大学" name="keywords"/>
#   <meta charset="utf-8"/>
#   <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
#   <meta content="width=device-width, initial-scale=1, shrink-to-fit=no" name="viewport"/>
#   <link href="css/style1.css" rel="stylesheet"/>
#   <link href="css/slick.css" rel="stylesheet"/>
#   <link href="css/swiper.css" rel="stylesheet"/>
#   <link href="css/jquery.hiSlider.min.css" rel="stylesheet"/>
#   <script src="js/bdtxk.js">
#   </script>
#   <script src="js/jquery-migrate.min.js">
#   </script>
#   <script src="js/slick.min.js">
#   </script>
#   <script src="js/SuperSlide.js" type="text/javascript">
#   </script>
#   <script src="js/myslideup.js" type="text/javascript">
#   </script>
#   <script src="js/hiSlider.min.js">
#   </script>
#   <style>
#    .fd table td{display:inline-block; float:right;}
#   </style>
#   <script>
#    window.addEventListener('mousewheel', function(event){
#     if (event.ctrlKey === true || event.metaKey) {
#           event.preventDefault();
#     }
# },{ passive: false});
#
# //firefox
#  window.addEventListener('DOMMouseScroll', function(event){
#     if (event.ctrlKey === true || event.metaKey) {
#            event.preventDefault();
#     }
# },{ passive: false});
#   </script>
#   <!--Announced by Visual SiteBuilder 9-->
#   <link href="_sitegray/_sitegray_d.css" rel="stylesheet" type="text/css"/>
#   <script language="javascript" src="_sitegray/_sitegray.js">
#   </script>
#   <!-- CustomerNO:77656262657232307e78465452565742000000054452 -->
#   <link href="index.vsb.css" rel="stylesheet" type="text/css"/>
#   <script devices="pc|pad" id="_vsbscreen" src="/system/resource/js/vsbscreen.min.js" type="text/javascript">
#   </script>
#   <script src="/system/resource/js/counter.js" type="text/javascript">
#   </script>
#   <script type="text/javascript">
#    _jsq_(1001,'/index.jsp',-1,1556346165)
#   </script>
#  </head>
#  <body>
#   <div class="fd" style="display:none">
#    <script language="javascript" src="/system/resource/js/dynclicks.js">
#    </script>
#    <div id="adu0" style="Z-index:10;LEFT: 0px; POSITION: absolute; TOP: 0px" width="159">
#     <iframe frameborder="0" src="about:blank" style="position:absolute;Z-index:-1;width:100%;height:100%;top:0;left:0;scrolling:no;filter:progid:DXImageTransform.Microsoft.Alpha(style=0,opacity=0)">
#     </iframe>
#     <table border="0" cellpadding="0" cellspacing="0">
#      <tbody>
#       <tr align="center">
#        <td align="left">
#         <a href="http://news.cufe.edu.cn/ztxw1/dsxxjy.htm" onclick="_addDynClicks('wbimage',1556346165,53427)" target="_blank" title="">
#          <img border="0" height="162" src="images/zt_ds.png" width="280"/>
#         </a>
#        </td>
#       </tr>
#       <tr>
#        <td align="right" style="padding-top:1px">
#         <table border="0" cellpadding="10" cellspacing="0">
#          <tr>
#           <td style="background-color:#f5f5f5;padding:1px">
#            <a class="closestyle248288" href="javascript:showimagecloseu0();">
#             关闭
#            </a>
#           </td>
#          </tr>
#         </table>
#        </td>
#       </tr>
#      </tbody>
#     </table>
#    </div>
#    <script>
#     function showimagecloseu0()
# {
#     var obju0=document.getElementById("adu0");
#     obju0.style.display = 'none';
# };
# //水平             //上下
#
# var xu0 = 0;yu0 = 0;
#
# var xinu0 = true; yinu0 = true;
# var stepu0 = 1;
#
# var delayu0 = 88;
#
# var obju0=document.getElementById("adu0");
# var bdyu0 = document.body;
#     if (document.compatMode && document.compatMode != "BackCompat")
#         bdyu0 = document.documentElement;
#     else
#         bdyu0 = document.body;
# function floatADu0()
# {
#     var bdy_scrollTop = document.body.scrollTop | document.documentElement.scrollTop;
#     var Lu0=Tu0=0;
#     var Ru0= bdyu0.clientWidth-obju0.offsetWidth;
#     var Bu0 = bdyu0.clientHeight-obju0.offsetHeight;
#     obju0.style.left = xu0 + bdyu0.scrollLeft+"px";
#     obju0.style.top = yu0 + bdy_scrollTop+"px";
#     xu0 = xu0 + stepu0*(xinu0?1:-1);
#     if(xu0 < Lu0)
#     {
#         xinu0 = true;
#         xu0 = Lu0;
#     }
#     if(xu0 > Ru0)
#     {
#         xinu0 = false;
#         xu0 = Ru0;
#     }
#     yu0 = yu0 + stepu0*(yinu0?1:-1);
#     if(yu0 < Tu0)
#     {
#         yinu0 = true;
#         yu0 = Tu0;
#     }
#     if(yu0 > Bu0)
#     {
#         yinu0 = false;
#         yu0 = Bu0;
#     }
# }
# var itlu0;
# if(window.navigator.userAgent.indexOf("MSIE")>=1)
# {
#     window.attachEvent('onload', adftu0);
# }
# else
# {
#     window.addEventListener('load',adftu0, false);
# }
# function adftu0()
# {
#     itlu0 = setInterval("floatADu0()", delayu0);
# }
#     obju0.onmouseover=function(){clearInterval(itlu0);};
#     obju0.onmouseout=function(){itlu0=setInterval("floatADu0()", delayu0)};
#    </script>
#   </div>
#   <div class="nav">
#    <div class="container2">
#     <div class="subMenu ui-header">
#      <div class="ui-header-box">
#       <div class="ui-header-nav">
#        <dl>
#         <dd class="sy">
#          <h3>
#           <a href="index.htm">
#            首页
#           </a>
#          </h3>
#         </dd>
#         <dd>
#          <h3>
#           <a href="xxgk/xxjj.htm">
#            学校概况
#           </a>
#          </h3>
#          <ul style="display: none;">
#           <li>
#            <a href="xxgk/xxjj.htm">
#             学校简介
#            </a>
#           </li>
#           <li>
#            <a href="xxgk/lsyg.htm">
#             历史沿革
#            </a>
#           </li>
#           <li>
#            <a href="xxgk/lrld.htm">
#             历任领导
#            </a>
#           </li>
#           <li>
#            <a href="xxgk/xrld.htm">
#             现任领导
#            </a>
#           </li>
#           <li>
#            <a href="xxgk/xxzc.htm">
#             学校章程
#            </a>
#           </li>
#           <li>
#            <a href="http://int.cufe.edu.cn/" target="_blank">
#             国际合作
#            </a>
#           </li>
#           <li>
#            <a href="http://xkjs.cufe.edu.cn/" target="_blank">
#             学科建设
#            </a>
#           </li>
#           <li>
#            <a href="xxgk/xxbs.htm">
#             学校标识
#            </a>
#           </li>
#           <li>
#            <a href="xxgk/tjxx.htm">
#             统计信息
#            </a>
#           </li>
#          </ul>
#         </dd>
#         <dd>
#          <h3>
#           <a href="zzjg/xysz.htm">
#            学院设置
#           </a>
#          </h3>
#         </dd>
#         <dd>
#          <h3>
#           <a href="zzjg/xysz.htm">
#            组织机构
#           </a>
#          </h3>
#          <ul style="display: none;">
#           <li>
#            <a href="zzjg/xysz.htm">
#             学院设置
#            </a>
#           </li>
#           <li>
#            <a href="zzjg/dzfw.htm">
#             党政服务
#            </a>
#           </li>
#           <li>
#            <a href="zzjg/kyjg.htm">
#             科研机构
#            </a>
#           </li>
#          </ul>
#         </dd>
#         <dd>
#          <h3>
#           <a href="rcpy.htm">
#            人才培养
#           </a>
#          </h3>
#          <ul style="display: none;">
#           <li>
#            <a href="http://jwc.cufe.edu.cn/index.htm" target="_blank">
#             本科生教育
#            </a>
#           </li>
#           <li>
#            <a href="http://gs.cufe.edu.cn/" target="_blank">
#             研究生教育
#            </a>
#           </li>
#           <li>
#            <a href="http://sice.cufe.edu.cn/" target="_blank">
#             留学生教育
#            </a>
#           </li>
#           <li>
#            <a href="http://sce.cufe.edu.cn/" target="_blank">
#             继续教育
#            </a>
#           </li>
#           <li>
#            <a href="rcpy/szdw.htm">
#             师资队伍
#            </a>
#           </li>
#          </ul>
#         </dd>
#         <dd>
#          <h3>
#           <a href="zsjy.htm">
#            招生就业
#           </a>
#          </h3>
#          <ul style="display: none;">
#           <li>
#            <a href="http://zs.cufe.edu.cn/">
#             本科生招生
#            </a>
#           </li>
#           <li>
#            <a href="http://gs.cufe.edu.cn/zsgz/sszs_sz_.htm">
#             研究生招生
#            </a>
#           </li>
#           <li>
#            <a href="http://sice.cufe.edu.cn/zsxx1.htm">
#             留学生招生
#            </a>
#           </li>
#           <li>
#            <a href="http://mba.cufe.edu.cn/zs1.htm">
#             MBA招生
#            </a>
#           </li>
#           <li>
#            <a href="http://sce.cufe.edu.cn/zsbm.htm">
#             继续教育招生
#            </a>
#           </li>
#           <li>
#            <a href="http://scc.cufe.edu.cn/f/home/index/">
#             就业创业
#            </a>
#           </li>
#          </ul>
#         </dd>
#         <dd>
#          <h3>
#           <a href="kxyj.htm">
#            科学研究
#           </a>
#          </h3>
#          <ul style="display: none;">
#           <li>
#            <a href="zzjg/kyjg.htm">
#             科研机构
#            </a>
#           </li>
#           <li>
#            <a href="http://kyxt.cufe.edu.cn/userAction!to_login.action">
#             科研管理
#            </a>
#           </li>
#           <li>
#            <a href="http://postdoctor.cufe.edu.cn/">
#             博士后
#            </a>
#           </li>
#           <li>
#            <a href="http://xsqks.cufe.edu.cn/">
#             学术期刊
#            </a>
#           </li>
#           <li>
#            <a href="http://kyc.cufe.edu.cn/kydt.htm">
#             科研动态
#            </a>
#           </li>
#          </ul>
#         </dd>
#         <dd>
#          <h3>
#           <a href="fwzn.htm">
#            服务指南
#           </a>
#          </h3>
#          <ul style="display: none;">
#           <li>
#            <a href="http://i.cufe.edu.cn">
#             校园门户
#            </a>
#           </li>
#           <li>
#            <a href="mailto:secretary@cufe.edu.cn">
#             书记信箱
#            </a>
#           </li>
#           <li>
#            <a href="mailto:president@cufe.edu.cn">
#             校长信箱
#            </a>
#           </li>
#           <li>
#            <a href="http://op.cufe.edu.cn/xxgk/xxgk/xxgkjtsx.htm">
#             信息公开
#            </a>
#           </li>
#           <li>
#            <a href="fwzn/zcxl.htm">
#             中财校历
#            </a>
#           </li>
#           <li>
#            <a href="http://op.cufe.edu.cn/index/mzhyap.htm">
#             本周会议
#            </a>
#           </li>
#           <li>
#            <a href="fwzn/bgdh.htm">
#             办公电话
#            </a>
#           </li>
#           <li>
#            <a href="fwzn/xxjg.htm">
#             学校景观
#            </a>
#           </li>
#          </ul>
#         </dd>
#        </dl>
#       </div>
#      </div>
#     </div>
#    </div>
#   </div>
#   <div class="top">
#    <div class="container2">
#     <!-- 网站logo图片地址请在本组件"内容配置-网站logo"处填写 -->
#     <a class="fl logo" href="index.htm">
#      <img alt="" src="images/logo2.png"/>
#     </a>
#     <div class="linkbox fr">
#      <script language="javascript" src="/system/resource/js/openlink.js">
#      </script>
#      <a class="linkxx fl" href="http://en.cufe.edu.cn/" onclick='_addDynClicks("wburl", 1556346165, 1001)' title="">
#       English
#      </a>
#     </div>
#     <div class="search fr">
#      <script type="text/javascript">
#       function _nl_ys_check(){
#
#         var keyword = document.getElementById('showkeycode246121').value;
#         if(keyword==null||keyword==""){
#             alert("请输入你要检索的内容！");
#             return false;
#         }
#         if(window.toFF==1)
#         {
#             document.getElementById("lucenenewssearchkey246121").value = Simplized(keyword );
#         }else
#         {
#             document.getElementById("lucenenewssearchkey246121").value = keyword;
#         }
#         var  base64 = new Base64();
#         document.getElementById("lucenenewssearchkey246121").value = base64.encode(document.getElementById("lucenenewssearchkey246121").value);
#         new VsbFormFunc().disableAutoEnable(document.getElementById("showkeycode246121"));
#         return true;
#     }
#      </script>
#      <form action="ssjgy.jsp?wbtreeid=1001" id="au4a" method="post" name="au4a" onsubmit="return _nl_ys_check()" style="display: inline">
#       <input id="lucenenewssearchkey246121" name="lucenenewssearchkey" type="hidden" value=""/>
#       <input id="_lucenesearchtype246121" name="_lucenesearchtype" type="hidden" value="1"/>
#       <input id="searchScope246121" name="searchScope" type="hidden" value="0"/>
#       <input class="search-input" id="showkeycode246121" name="showkeycode" onblur="if(this.value == '')this.value='请输入搜索内容';" onclick="if(this.value == '请输入搜索内容')this.value='';" value="请输入搜索内容"/>
#       <input class="search-btn" src="images/serbtn.png" type="image"/>
#      </form>
#      <script language="javascript" src="/system/resource/js/base64.js">
#      </script>
#      <script language="javascript" src="/system/resource/js/formfunc.js">
#      </script>
#     </div>
#     <div style="clear: both;">
#     </div>
#    </div>
#   </div>
#   <div id="wrap" style="position: relative;">
#    <ul class="hiSlider hiSlider1">
#     <a href="https://mp.weixin.qq.com/s/6oAroFdUds_YW8PRXt1Mow" target="_blank">
#      <li class="hiSlider-item" data-title="">
#       <img src="images/funvjiebanner2fuben.jpg"/>
#      </li>
#     </a>
#     <a href="https://mp.weixin.qq.com/s/mV9mgNhhF44Kp5v5gSls6w" target="_blank">
#      <li class="hiSlider-item" data-title="">
#       <img src="images/lianghuibanner.jpg"/>
#      </li>
#     </a>
#     <a href="https://mp.weixin.qq.com/s/gaN67ocuuww6OCFxMDJAAw" target="_blank">
#      <li class="hiSlider-item" data-title="">
#       <img src="images/weixintupian_20220220182957.jpg"/>
#      </li>
#     </a>
#     <a href="https://mp.weixin.qq.com/s/BbUKjXkSm62fAY8e60ilfQ" target="_blank">
#      <li class="hiSlider-item" data-title="">
#       <img src="images/WechatIMG10182.png"/>
#      </li>
#     </a>
#     <a href="https://mp.weixin.qq.com/s/UsW6Lx3Ov6ufY_VjrVYnGw" target="_blank">
#      <li class="hiSlider-item" data-title="">
#       <img src="images/kaixue.jpg"/>
#      </li>
#     </a>
#    </ul>
#    <a class="wqhg_icon" href="index/wqhg.htm" target="_blank">
#     往期回顾
#    </a>
#   </div>
#   <div class="wz" style="display: none;">
#    <img height="58" src="images/xqtt.png" width="824"/>
#   </div>
#   <div class="sy_notice" style="display: block;">
#    <ul style="display: none;">
#     <marquee direction="left" height="40" onmouseout="this.start()" onmouseover="this.stop()" scrollamount="2" scrolldelay="6">
#      <script language="javascript" src="/system/resource/js/centerCutImg.js">
#      </script>
#      <script language="javascript" src="/system/resource/js/ajax.js">
#      </script>
#      <li>
#       <a href="http://news.cufe.edu.cn/info/1002/49878.htm" style="font-weight:bold;color:#b51d1d;" target="_blank" title="中央财经大学二〇二一年新年贺词：奋力谱写建设一流大学新篇章！">
#        中央财经大学二〇二一年新年贺词：奋力谱写建设一流大学新篇章！
#       </a>
#      </li>
#      <li>
#       <a href="http://www.cufe.edu.cn/info/1186/11242.htm" target="_blank" title="收视通知：12月28日-31日，北京广播电视台连续播出我校4集思政宣传片,敬请收看。">
#        收视通知：12月28日-31日，北京广播电视台连续播出我校4集思政宣传片,敬请收看。
#       </a>
#      </li>
#      <script>
#       _showDynClickBatch(['dynclicks_u7_11286','dynclicks_u7_11285'],[11286,11285],"wbnews", 1556346165)
#      </script>
#     </marquee>
#    </ul>
#   </div>
#   <div class="xw" style="padding-top: 20px;">
#    <div class="container" style="position: relative;">
#     <div class="head-news fl">
#      <h1>
#       头条新闻
#      </h1>
#      <a class="moreLink" href="http://news.cufe.edu.cn/ttxw.htm" onfocus="undefined" target="_blank">
#       <img alt="" src="images/morelj.png"/>
#      </a>
#      <div class="hd">
#       <ul class="timelist">
#        <li class="t1 active">
#         <i>
#         </i>
#         28
#         <span>
#          2022.02
#         </span>
#        </li>
#        <li class="t2">
#         <i>
#         </i>
#         24
#         <span>
#          2022.02
#         </span>
#        </li>
#        <li class="t3">
#         <i>
#         </i>
#         14
#         <span>
#          2022.02
#         </span>
#        </li>
#        <li class="t4">
#         <i>
#         </i>
#         28
#         <span>
#          2022.01
#         </span>
#        </li>
#        <li class="t5">
#         <i>
#         </i>
#         30
#         <span>
#          2021.12
#         </span>
#        </li>
#       </ul>
#      </div>
#      <div class="bd">
#       <div class="headlinelist slick" id="slick2">
#        <div>
#         <a href="http://news.cufe.edu.cn/info/1002/52493.htm">
#          <img src="/__local/9/1A/D2/7FE3638473C822CDCAF454B16F6_A5AAB80B_1527F.png" style="width:420px;height:270px;"/>
#         </a>
#         <div class="figurewrap">
#          <h2>
#           <a class="jiequ" href="http://news.cufe.edu.cn/info/1002/52493.htm" target="_blank" title="中央财经大学2022年春季学期本科线上教学顺利开课">
#            中央财经大学2022年春季学期本科线上教...
#           </a>
#          </h2>
#          <p class="inner">
#           2月28日上午8点整，我校本科线上教学准时开课。校长王瑶琪，副校长孙国辉，校长助理李涛及教务处负责人...
#          </p>
#         </div>
#        </div>
#        <div>
#         <a href="http://news.cufe.edu.cn/info/1002/52472.htm">
#          <img src="/__local/2/C1/5F/4EEDEF528E0763D200751314223_CBA53B03_B72CB.png" style="width:420px;height:270px;"/>
#         </a>
#         <div class="figurewrap">
#          <h2>
#           <a class="jiequ" href="http://news.cufe.edu.cn/info/1002/52472.htm" target="_blank" title="中央财经大学与中国人寿财产保险股份有限公司签署战略合作协议">
#            中央财经大学与中国人寿财产保险股份有...
#           </a>
#          </h2>
#          <p class="inner">
#           2月23日，中央财经大学与中国人寿财产保险股份有限公司战略合作协议签约仪式在中国人寿中心举行。中央财...
#          </p>
#         </div>
#        </div>
#        <div>
#         <a href="http://news.cufe.edu.cn/info/1121/52445.htm">
#          <img src="/__local/B/F5/B0/C96F90A9D15D609D5D767562CBF_AFB6722C_346DC.jpg" style="width:420px;height:270px;"/>
#         </a>
#         <div class="figurewrap">
#          <h2>
#           <a class="jiequ" href="http://news.cufe.edu.cn/info/1121/52445.htm" target="_blank" title="《新闻联播》报道我校《领航》快闪活动">
#            《新闻联播》报道我校《领航》快闪活动
#           </a>
#          </h2>
#          <p class="inner">
#           今天的《新闻联播》用2分零1秒的画面，报道我校《领航》快闪活动。虎年新春伊始，中财大人用歌声表达对...
#          </p>
#         </div>
#        </div>
#        <div>
#         <a href="http://news.cufe.edu.cn/info/1002/52397.htm">
#          <img src="/__local/B/94/96/9283206900947F51B39E6508C8A_D40D82C8_1688C.png" style="width:420px;height:270px;"/>
#         </a>
#         <div class="figurewrap">
#          <h2>
#           <a class="jiequ" href="http://news.cufe.edu.cn/info/1002/52397.htm" target="_blank" title="中央财经大学与北京银行签署战略合作协议，共促绿色金融发展">
#            中央财经大学与北京银行签署战略合作协...
#           </a>
#          </h2>
#          <p class="inner">
#           1月28日，中央财经大学与北京银行战略合作协议暨“中央财经大学-北京银行双碳与金融研究中心”揭牌仪式...
#          </p>
#         </div>
#        </div>
#        <div>
#         <a href="info/1238/14018.htm">
#          <img src="/__local/1/C5/48/96E93184B4A998E93E4F83EC57B_5C2BD46D_24473.jpg" style="width:420px;height:270px;"/>
#         </a>
#         <div class="figurewrap">
#          <h2>
#           <a class="jiequ" href="info/1238/14018.htm" style="font-weight:bold;color:#b51d1d;" target="_blank" title="中央财经大学二〇二二年新年贺词：用奋斗续写不凡！">
#            中央财经大学二〇二二年新年贺词：用奋...
#           </a>
#          </h2>
#          <p class="inner">
#           美编：校新闻通讯社美编团队 “财宝儿日记”插画
#          </p>
#         </div>
#        </div>
#       </div>
#      </div>
#      <script>
#       $(function (){
#     var owner='1556346165';
#     var contentid='220653';
#     var number='5';
#     var titlelen='20';
#     var summarylen='50';
#     $.ajax({
#         url : "/system/resource/news/newsservices.jsp",
#         type: "post",
#         data:{"owner":owner,"contentid":contentid,"number":number,"titlelen":titlelen,"summarylen":summarylen},
#         dataType : "json",
#         contentType : "application/x-www-form-urlencoded; charset=UTF-8",
#         async : false,
#         success : function(data) {
#             $.each(data,function(i,item)
#             {
#                 var showClickTimes=item.showClickTimes; //点击数
#                 //$(".looknum").eq(i).text(showClickTimes);
#                 var clickHtml="<span id='dynclicks_u5_'"+i+" name='dynclicks_u5'>"+showClickTimes+"</span>";
#                 $(".looknum").eq(i).html(clickHtml);
#
#             });
#         },
#     error: function(XMLHttpRequest, textStatus, errorThrown) {
#             //alert(textStatus);
#             //alert("请检查数据库连接池是否开通!");
#         },
#         complete: function(XMLHttpRequest, textStatus) {
#         this; // 调用本次AJAX请求时传递的options参数
#         }
#     });
# })
#      </script>
#      <script>
#       _showDynClickBatch(['dynclicks_u8_14168','dynclicks_u8_14146','dynclicks_u8_14139','dynclicks_u8_14121','dynclicks_u8_14018'],[14168,14146,14139,14121,14018],"wbnews", 1556346165)
#      </script>
#     </div>
#     <div class="ywky fl">
#      <div class="xxyw fl">
#       <div class="ggTab" id="xw">
#        <h1>
#         学校要闻
#         <a href="http://news.cufe.edu.cn/index.htm" onfocus="undefined" style="color: rgb(21, 100, 195); font-size: 14px;" target="_blank">
#          &gt;&gt;进入新闻网
#         </a>
#        </h1>
#        <a class="moreLink" href="http://news.cufe.edu.cn/zhyw.htm" onfocus="undefined">
#         <img alt="" src="images/morelj.png"/>
#        </a>
#       </div>
#       <ul class="xxywList">
#        <li>
#         <p>
#          <a href="http://news.cufe.edu.cn/info/1002/52542.htm" target="_blank" title="北京冬奥组委机场运行团队向我校发来感谢信">
#           北京冬奥组委机场运行团队向我校发来感谢信
#          </a>
#          <span>
#           03-11
#          </span>
#         </p>
#        </li>
#        <li>
#         <p>
#          <a href="http://news.cufe.edu.cn/info/1002/52539.htm" target="_blank" title="我校2位教师主持的国家自科基金项目绩效评估获评“特优”">
#           我校2位教师主持的国家自科基金项目绩效...
#          </a>
#          <span>
#           03-11
#          </span>
#         </p>
#        </li>
#        <li>
#         <p>
#          <a href="http://news.cufe.edu.cn/info/1002/52525.htm" target="_blank" title="中央财经大学师生热议“两会”">
#           中央财经大学师生热议“两会”
#          </a>
#          <span>
#           03-07
#          </span>
#         </p>
#        </li>
#        <li>
#         <p>
#          <a href="http://news.cufe.edu.cn/info/1002/52523.htm" target="_blank" title="教育部网站报道中央财经大学北京冬奥会志愿服务工作">
#           教育部网站报道中央财经大学北京冬奥会...
#          </a>
#          <span>
#           03-07
#          </span>
#         </p>
#        </li>
#        <li>
#         <p>
#          <a href="http://news.cufe.edu.cn/info/1002/52502.htm" target="_blank" title="中央财经大学召开2022年度工作布置会">
#           中央财经大学召开2022年度工作布置会
#          </a>
#          <span>
#           03-02
#          </span>
#         </p>
#        </li>
#        <li>
#         <p>
#          <a href="http://news.cufe.edu.cn/info/1002/52544.htm" target="_blank" title="中财大志愿者赵建铭登上冬残奥会闭幕式">
#           中财大志愿者赵建铭登上冬残奥会闭幕式
#          </a>
#          <span>
#           03-13
#          </span>
#         </p>
#        </li>
#        <li>
#         <p>
#          <a href="http://news.cufe.edu.cn/info/1002/52531.htm" target="_blank" title="全国政协委员贺强教授携8份提案上两会">
#           全国政协委员贺强教授携8份提案上两会
#          </a>
#          <span>
#           03-09
#          </span>
#         </p>
#        </li>
#        <li>
#         <p>
#          <a href="http://news.cufe.edu.cn/info/1002/52526.htm" target="_blank" title="中财大，因她更美！">
#           中财大，因她更美！
#          </a>
#          <span>
#           03-08
#          </span>
#         </p>
#        </li>
#        <li>
#         <p>
#          <a href="http://news.cufe.edu.cn/info/1002/52514.htm" target="_blank" title="我校举行2022年春季教师思想动态调研工作座谈会">
#           我校举行2022年春季教师思想动态调研工...
#          </a>
#          <span>
#           03-04
#          </span>
#         </p>
#        </li>
#        <li>
#         <p>
#          <a href="http://news.cufe.edu.cn/info/1002/52524.htm" target="_blank" title="校纪委对春季学期开学和疫情防控进行专项调研监督">
#           校纪委对春季学期开学和疫情防控进行专...
#          </a>
#          <span>
#           03-07
#          </span>
#         </p>
#        </li>
#        <li>
#         <p>
#          <a href="http://news.cufe.edu.cn/info/1002/52513.htm" target="_blank" title="守护校园不打烊 践行初心保平安">
#           守护校园不打烊 践行初心保平安
#          </a>
#          <span>
#           03-04
#          </span>
#         </p>
#        </li>
#       </ul>
#       <script>
#        _showDynClickBatch(['dynclicks_u9_14219','dynclicks_u9_14217','dynclicks_u9_14204','dynclicks_u9_14201','dynclicks_u9_14182','dynclicks_u9_14220','dynclicks_u9_14210','dynclicks_u9_14206','dynclicks_u9_14196','dynclicks_u9_14203','dynclicks_u9_14200'],[14219,14217,14204,14201,14182,14220,14210,14206,14196,14203,14200],"wbnews", 1556346165)
#       </script>
#      </div>
#      <div class="xykx fl">
#       <div class="ggTab">
#        <h1>
#         教学科研
#        </h1>
#        <a class="moreLink" href="index/jxky.htm" onfocus="undefined" target="_blank">
#         <img alt="" src="images/morelj.png"/>
#        </a>
#       </div>
#       <ul>
#        <li class="item1" style="padding-bottom:8px;">
#         <div class="pic">
#          <img alt="" src="/__local/B/65/0C/5A3EEACD0A122B96A0A49AEFC4B_6A321889_51609.png" style="width:290px;height:135px;"/>
#         </div>
#         <a href="http://news.cufe.edu.cn/info/1002/52492.htm" style="margin-top:9px;" title="我校研究生春季学期教学“云”端开启！">
#          我校研究生春季学期教学“云”端开启！
#         </a>
#        </li>
#        <li>
#         <a href="http://news.cufe.edu.cn/info/1002/52539.htm" style="margin-top:8px;" title="我校2位教师主持的国家自科基金项目绩效评估获评“特优”">
#          我校2位教师主持的国家自科基金项目...
#         </a>
#        </li>
#        <li>
#         <a href="http://news.cufe.edu.cn/info/1003/52528.htm" title="我校教师三篇论文被《新华文摘》全文转载">
#          我校教师三篇论文被《新华文摘》全...
#         </a>
#        </li>
#        <li>
#         <a href="info/1185/14197.htm" title="我校童伟研究员论文被《新华文摘》论点摘编">
#          我校童伟研究员论文被《新华文摘》...
#         </a>
#        </li>
#        <li>
#         <a href="http://news.cufe.edu.cn/info/1002/52493.htm" title="中央财经大学2022年春季学期本科线上教学顺利开课">
#          中央财经大学2022年春季学期本科线...
#         </a>
#        </li>
#        <li>
#         <a href="http://news.cufe.edu.cn/info/1003/52508.htm" title="我校教师合作研究成果在 The Accounting Review发表">
#          我校教师合作研究成果在 The Accoun...
#         </a>
#        </li>
#        <li>
#         <a href="http://news.cufe.edu.cn/info/1002/52490.htm" title="我校获批教育部首批虚拟教研室建设试点">
#          我校获批教育部首批虚拟教研室建设试点
#         </a>
#        </li>
#       </ul>
#       <script>
#        _showDynClickBatch(['dynclicks_u10_14163','dynclicks_u10_14218','dynclicks_u10_14209','dynclicks_u10_14197','dynclicks_u10_14165','dynclicks_u10_14187','dynclicks_u10_14158'],[14163,14218,14209,14197,14165,14187,14158],"wbnews", 1556346165)
#       </script>
#      </div>
#      <div class="clear">
#      </div>
#     </div>
#     <div class="kstd">
#      <ul>
#       <li>
#        <a href="http://i.cufe.edu.cn" target="_blank" title="">
#         校园门户
#        </a>
#       </li>
#       <li>
#        <a href="https://ehall.cufe.edu.cn/v2/site/index" target="_blank" title="">
#         办事大厅
#        </a>
#       </li>
#       <li>
#        <a href="http://oa.cufe.edu.cn/seeyon/main.do?method=main" target="_blank" title="">
#         OA系统
#        </a>
#       </li>
#       <li>
#        <a href="http://pay.cufe.edu.cn/payment/" target="_blank" title="">
#         缴费平台
#        </a>
#       </li>
#       <li>
#        <a href="https://exmail.qq.com/login" target="_blank" title="">
#         邮件系统
#        </a>
#       </li>
#       <li>
#        <a href="http://xuanke.cufe.edu.cn/jwglxt" target="_blank" title="">
#         教务系统
#        </a>
#       </li>
#       <li>
#        <a href="http://kyxt.cufe.edu.cn/userAction!to_login.action" target="_blank" title="">
#         科研系统
#        </a>
#       </li>
#       <li>
#        <a href="http://zhicheng.cufe.edu.cn/base/frame/main_zycjdx.jsp;jsessionid=81C5B397F6A43579A555792C2FBDB2B4" target="_blank" title="">
#         人事系统
#        </a>
#       </li>
#       <li>
#        <a href="http://opac.cufe.edu.cn:8080/reader/hwthau.php" target="_blank" title="">
#         图书系统
#        </a>
#       </li>
#       <li>
#        <a href="http://cwgl.cufe.edu.cn/WFManager/login.jsp" target="_blank" title="">
#         财务系统
#        </a>
#       </li>
#       <li>
#        <a href="https://online.cufe.edu.cn/" target="_blank" title="在线学堂">
#         在线学堂
#        </a>
#       </li>
#      </ul>
#      <i>
#       <img src="images/ksdhlogo.png"/>
#      </i>
#     </div>
#     <div style="clear: both;">
#     </div>
#    </div>
#   </div>
#   <div class="gg">
#    <div class="ggTab">
#     <div class="container">
#      <span class="on">
#       <a href="index/tzgg1.htm">
#        通知公告
#       </a>
#      </span>
#      <span>
#       <a href="index/bgjz.htm">
#        报告讲座
#       </a>
#      </span>
#      <span>
#       <a href="index/zbxx.htm">
#        招标信息
#       </a>
#      </span>
#      <span>
#       <a href="index/zcgg.htm">
#        自采公告
#       </a>
#      </span>
#      <span style="background: none;">
#       <a href="http://op.cufe.edu.cn/xxgk/xxgk/xxgkjtsx.htm">
#        信息公开
#       </a>
#      </span>
#     </div>
#    </div>
#    <div class="ggCon">
#     <div class="container">
#      <ul>
#       <li>
#        <p>
#         <span class="fl">
#          03-08
#         </span>
#         <a class="fl" href="info/1186/14208.htm" title="中央财经大学与美国史蒂文斯理工学院合作举办企业项目管理理学硕士学位教育项目2022年招生简章">
#          <b>
#           中央财经大学与美国史蒂文斯理工学院合作举办企业项目管...
#          </b>
#         </a>
#        </p>
#       </li>
#       <li>
#        <p>
#         <span class="fl">
#          03-11
#         </span>
#         <a class="fl" href="info/1186/14214.htm" title="关于2022年度非教学科研岗位招聘面试相关事宜的通知">
#          <b>
#           关于2022年度非教学科研岗位招聘面试相关事宜的通知
#          </b>
#         </a>
#        </p>
#       </li>
#       <li>
#        <p>
#         <span class="fl">
#          03-09
#         </span>
#         <a class="fl" href="info/1186/14212.htm" title="2022年上半年北京市中小学教师资格考试（笔试） 中央财经大学考点温馨提示">
#          <b>
#           2022年上半年北京市中小学教师资格考试（笔试） 中央财经...
#          </b>
#         </a>
#        </p>
#       </li>
#       <li>
#        <p>
#         <span class="fl">
#          03-09
#         </span>
#         <a class="fl" href="info/1186/14211.htm" title="关于2022年上半年北京市中小学教师资格考试期间沙河校区实行临时校园管控的通知">
#          <b>
#           关于2022年上半年北京市中小学教师资格考试期间沙河校区...
#          </b>
#         </a>
#        </p>
#       </li>
#       <li>
#        <p>
#         <span class="fl">
#          03-07
#         </span>
#         <a class="fl" href="info/1186/14205.htm" title="中央财经大学教师工作部、人事处、人才工作办公室非教学科研岗招聘公告">
#          <b>
#           中央财经大学教师工作部、人事处、人才工作办公室非教学...
#          </b>
#         </a>
#        </p>
#       </li>
#       <li>
#        <p>
#         <span class="fl">
#          03-02
#         </span>
#         <a class="fl" href="info/1186/14181.htm" title="关于拟调入林雯博士的公示">
#          <b>
#           关于拟调入林雯博士的公示
#          </b>
#         </a>
#        </p>
#       </li>
#       <li>
#        <p>
#         <span class="fl">
#          02-28
#         </span>
#         <a class="fl" href="info/1186/14159.htm" title="中央财经大学法学专业辅修学士学位招生简章（2022年）">
#          <b>
#           中央财经大学法学专业辅修学士学位招生简章（2022年）
#          </b>
#         </a>
#        </p>
#       </li>
#       <li>
#        <p>
#         <span class="fl">
#          01-21
#         </span>
#         <a class="fl" href="info/1186/14104.htm" title="中央财经大学财政税务学院行政教辅岗招聘启事（非事业编制）">
#          <b>
#           中央财经大学财政税务学院行政教辅岗招聘启事（非事业编制）
#          </b>
#         </a>
#        </p>
#       </li>
#       <li>
#        <p>
#         <span class="fl">
#          01-19
#         </span>
#         <a class="fl" href="info/1186/14087.htm" title="关于2022年寒假期间沙河校区校门及部分楼宇管理工作的通知">
#          <b>
#           关于2022年寒假期间沙河校区校门及部分楼宇管理工作的通...
#          </b>
#         </a>
#        </p>
#       </li>
#      </ul>
#      <script>
#       _showDynClickBatch(['dynclicks_u13_14208','dynclicks_u13_14214','dynclicks_u13_14212','dynclicks_u13_14211','dynclicks_u13_14205','dynclicks_u13_14181','dynclicks_u13_14159','dynclicks_u13_14104','dynclicks_u13_14087'],[14208,14214,14212,14211,14205,14181,14159,14104,14087],"wbnews", 1556346165)
#      </script>
#      <div class="moregg">
#       <a href="index/tzgg1.htm" onfocus="undefined">
#        &gt;&gt;更多
#       </a>
#      </div>
#     </div>
#    </div>
#    <div class="ggCon" style="display: none;">
#     <div class="container">
#      <ul>
#       <li>
#        <p>
#         <span class="fl">
#          01-06
#         </span>
#         <a class="fl" href="info/1187/14040.htm" title="中财MBA卓越讲坛第18讲：2022年房地产市场展望">
#          <b>
#           中财MBA卓越讲坛第18讲：2022年房地产市场展望
#          </b>
#         </a>
#        </p>
#       </li>
#       <li>
#        <p>
#         <span class="fl">
#          12-29
#         </span>
#         <a class="fl" href="info/1187/13996.htm" title="中财MBA卓越讲坛第17讲：从金融风险看集团资金管理">
#          <b>
#           中财MBA卓越讲坛第17讲：从金融风险看集团资金管理
#          </b>
#         </a>
#        </p>
#       </li>
#       <li>
#        <p>
#         <span class="fl">
#          12-17
#         </span>
#         <a class="fl" href="info/1187/13925.htm" title="【北京市双一流共建项目高端讲座】谈如何写好国家基金项目的申请书">
#          <b>
#           【北京市双一流共建项目高端讲座】谈如何写好国家基金项...
#          </b>
#         </a>
#        </p>
#       </li>
#       <li>
#        <p>
#         <span class="fl">
#          12-17
#         </span>
#         <a class="fl" href="info/1187/13918.htm" title="中央财经大学社会与心理学院2021学术年会（第十二届）">
#          <b>
#           中央财经大学社会与心理学院2021学术年会（第十二届）
#          </b>
#         </a>
#        </p>
#       </li>
#       <li>
#        <p>
#         <span class="fl">
#          12-15
#         </span>
#         <a class="fl" href="info/1187/13903.htm" title="中财MBA卓越讲坛第16讲：金融对可持续发展目标的促进作用——结合世界银行业务探讨">
#          <b>
#           中财MBA卓越讲坛第16讲：金融对可持续发展目标的促进作用...
#          </b>
#         </a>
#        </p>
#       </li>
#       <li>
#        <p>
#         <span class="fl">
#          12-09
#         </span>
#         <a class="fl" href="info/1187/13837.htm" title="第五届中国资产评估学术论坛暨《资产评估研究》2021年研讨会">
#          <b>
#           第五届中国资产评估学术论坛暨《资产评估研究》2021年研...
#          </b>
#         </a>
#        </p>
#       </li>
#       <li>
#        <p>
#         <span class="fl">
#          12-09
#         </span>
#         <a class="fl" href="info/1187/13825.htm" title="第十三届中国人力资本指数及报告发布暨人力资本国际研讨会">
#          <b>
#           第十三届中国人力资本指数及报告发布暨人力资本国际研讨会
#          </b>
#         </a>
#        </p>
#       </li>
#       <li>
#        <p>
#         <span class="fl">
#          11-30
#         </span>
#         <a class="fl" href="info/1187/13733.htm" title="（12月3日）CHLR 应用微观经济学研讨会系列讲座">
#          <b>
#           （12月3日）CHLR 应用微观经济学研讨会系列讲座
#          </b>
#         </a>
#        </p>
#       </li>
#       <li>
#        <p>
#         <span class="fl">
#          11-16
#         </span>
#         <a class="fl" href="info/1187/13606.htm" title="面向新发展格局的国有经济布局优化结构调整趋势与展望">
#          <b>
#           面向新发展格局的国有经济布局优化结构调整趋势与展望
#          </b>
#         </a>
#        </p>
#       </li>
#      </ul>
#      <script>
#       _showDynClickBatch(['dynclicks_u14_14040','dynclicks_u14_13996','dynclicks_u14_13925','dynclicks_u14_13918','dynclicks_u14_13903','dynclicks_u14_13837','dynclicks_u14_13825','dynclicks_u14_13733','dynclicks_u14_13606'],[14040,13996,13925,13918,13903,13837,13825,13733,13606],"wbnews", 1556346165)
#      </script>
#      <div class="moregg">
#       <a href="index/bgjz.htm" onfocus="undefined">
#        &gt;&gt;更多
#       </a>
#      </div>
#     </div>
#    </div>
#    <div class="ggCon" style="display: none;">
#     <div class="container">
#      <ul>
#       <li>
#        <p>
#         <span class="fl">
#          03-07
#         </span>
#         <a class="fl" href="info/1188/14202.htm" title="中央财经大学子佩心舍一层功能区后厨设备采购项目比选公告">
#          <b>
#           中央财经大学子佩心舍一层功能区后厨设备采购项目比选公告
#          </b>
#         </a>
#        </p>
#       </li>
#       <li>
#        <p>
#         <span class="fl">
#          01-29
#         </span>
#         <a class="fl" href="info/1188/14118.htm" title="中央财经大学沙河校区10、11、13号学院楼教学科研配套服务采购项目中标结果公告">
#          <b>
#           中央财经大学沙河校区10、11、13号学院楼教学科研配套服...
#          </b>
#         </a>
#        </p>
#       </li>
#       <li>
#        <p>
#         <span class="fl">
#          01-24
#         </span>
#         <a class="fl" href="info/1188/14148.htm" title="中央财经大学沙河校区学生服务用房公开招租项目更正公告">
#          <b>
#           中央财经大学沙河校区学生服务用房公开招租项目更正公告
#          </b>
#         </a>
#        </p>
#       </li>
#       <li>
#        <p>
#         <span class="fl">
#          01-13
#         </span>
#         <a class="fl" href="info/1188/14068.htm" title="中央财经大学科研论文语言（英语）润色 服务采购（第二次）中标结果公告">
#          <b>
#           中央财经大学科研论文语言（英语）润色 服务采购（第二次...
#          </b>
#         </a>
#        </p>
#       </li>
#       <li>
#        <p>
#         <span class="fl">
#          01-10
#         </span>
#         <a class="fl" href="info/1188/14055.htm" title="中央财经大学沙河校区学生服务用房公开招租项目成交结果公告">
#          <b>
#           中央财经大学沙河校区学生服务用房公开招租项目成交结果公告
#          </b>
#         </a>
#        </p>
#       </li>
#       <li>
#        <p>
#         <span class="fl">
#          01-07
#         </span>
#         <a class="fl" href="info/1188/14044.htm" title="中央财经大学沙河校区10、11、13号学院楼教学科研配套服务采购项目招标公告">
#          <b>
#           中央财经大学沙河校区10、11、13号学院楼教学科研配套服...
#          </b>
#         </a>
#        </p>
#       </li>
#       <li>
#        <p>
#         <span class="fl">
#          12-31
#         </span>
#         <a class="fl" href="info/1188/14015.htm" title="中央财经大学沙河校区学生服务用房公开招租项目比选公告">
#          <b>
#           中央财经大学沙河校区学生服务用房公开招租项目比选公告
#          </b>
#         </a>
#        </p>
#       </li>
#       <li>
#        <p>
#         <span class="fl">
#          12-30
#         </span>
#         <a class="fl" href="info/1188/14012.htm" title="中央财经大学科研论文语言（英语）润色服务采购（第二次）学校招标公告">
#          <b>
#           中央财经大学科研论文语言（英语）润色服务采购（第二次...
#          </b>
#         </a>
#        </p>
#       </li>
#       <li>
#        <p>
#         <span class="fl">
#          12-30
#         </span>
#         <a class="fl" href="info/1188/14011.htm" title="中央财经大学2022年中外文图书采购项目中标公告">
#          <b>
#           中央财经大学2022年中外文图书采购项目中标公告
#          </b>
#         </a>
#        </p>
#       </li>
#      </ul>
#      <script>
#       _showDynClickBatch(['dynclicks_u15_14202','dynclicks_u15_14118','dynclicks_u15_14148','dynclicks_u15_14068','dynclicks_u15_14055','dynclicks_u15_14044','dynclicks_u15_14015','dynclicks_u15_14012','dynclicks_u15_14011'],[14202,14118,14148,14068,14055,14044,14015,14012,14011],"wbnews", 1556346165)
#      </script>
#      <div class="moregg">
#       <a href="index/zbxx.htm" onfocus="undefined">
#        &gt;&gt;更多
#       </a>
#      </div>
#     </div>
#    </div>
#    <div class="ggCon" style="display: none;">
#     <div class="container">
#      <ul>
#       <li>
#        <p>
#         <span class="fl">
#          03-11
#         </span>
#         <a class="fl" href="info/1240/14216.htm" title="中央财经大学采购项目需求和结果公示表">
#          <b>
#           中央财经大学采购项目需求和结果公示表
#          </b>
#         </a>
#        </p>
#       </li>
#       <li>
#        <p>
#         <span class="fl">
#          03-11
#         </span>
#         <a class="fl" href="info/1240/14215.htm" title="中央财经大学采购项目需求和结果公示表">
#          <b>
#           中央财经大学采购项目需求和结果公示表
#          </b>
#         </a>
#        </p>
#       </li>
#       <li>
#        <p>
#         <span class="fl">
#          03-08
#         </span>
#         <a class="fl" href="info/1240/14207.htm" title="中央财经大学采购项目需求和结果公示表">
#          <b>
#           中央财经大学采购项目需求和结果公示表
#          </b>
#         </a>
#        </p>
#       </li>
#       <li>
#        <p>
#         <span class="fl">
#          03-04
#         </span>
#         <a class="fl" href="info/1240/14194.htm" title="中央财经大学采购项目需求和结果公示表">
#          <b>
#           中央财经大学采购项目需求和结果公示表
#          </b>
#         </a>
#        </p>
#       </li>
#       <li>
#        <p>
#         <span class="fl">
#          03-01
#         </span>
#         <a class="fl" href="info/1240/14178.htm" title="中央财经大学采购项目需求和结果公示表">
#          <b>
#           中央财经大学采购项目需求和结果公示表
#          </b>
#         </a>
#        </p>
#       </li>
#       <li>
#        <p>
#         <span class="fl">
#          03-01
#         </span>
#         <a class="fl" href="info/1240/14176.htm" title="中央财经大学学院南路校区2022年八台无负压二次供水泵二次供水检测后勤服务产业集团自采项目采购公告">
#          <b>
#           中央财经大学学院南路校区2022年八台无负压二次供水泵二...
#          </b>
#         </a>
#        </p>
#       </li>
#       <li>
#        <p>
#         <span class="fl">
#          03-01
#         </span>
#         <a class="fl" href="info/1240/14175.htm" title="中央财经大学学院南路校区学四楼、学六楼、学术会堂门禁维修后勤服务产业集团自采项目采购公告(第三轮)">
#          <b>
#           中央财经大学学院南路校区学四楼、学六楼、学术会堂门禁...
#          </b>
#         </a>
#        </p>
#       </li>
#       <li>
#        <p>
#         <span class="fl">
#          03-01
#         </span>
#         <a class="fl" href="info/1240/14174.htm" title="中央财经大学采购项目需求和结果公示表">
#          <b>
#           中央财经大学采购项目需求和结果公示表
#          </b>
#         </a>
#        </p>
#       </li>
#       <li>
#        <p>
#         <span class="fl">
#          03-01
#         </span>
#         <a class="fl" href="info/1240/14173.htm" title="中央财经大学采购项目需求和结果公示表">
#          <b>
#           中央财经大学采购项目需求和结果公示表
#          </b>
#         </a>
#        </p>
#       </li>
#      </ul>
#      <script>
#       _showDynClickBatch(['dynclicks_u16_14216','dynclicks_u16_14215','dynclicks_u16_14207','dynclicks_u16_14194','dynclicks_u16_14178','dynclicks_u16_14176','dynclicks_u16_14175','dynclicks_u16_14174','dynclicks_u16_14173'],[14216,14215,14207,14194,14178,14176,14175,14174,14173],"wbnews", 1556346165)
#      </script>
#      <div class="moregg">
#       <a href="index/zcgg.htm" onfocus="undefined">
#        &gt;&gt;更多
#       </a>
#      </div>
#     </div>
#    </div>
#   </div>
#   <div class="kslj">
#    <div class="container">
#     <div class="ggTab">
#      <div class="container">
#       <h1>
#        专题新闻
#       </h1>
#       <a class="moreLink" href="http://news.cufe.edu.cn/ztxw.htm" onfocus="undefined" target="_blank">
#        <img alt="" src="images/morelj.png"/>
#       </a>
#      </div>
#     </div>
#     <ul style="clear:both">
#      <li>
#       <a href="http://news.cufe.edu.cn/ztxw1/xxxjpxsdzgtsshzysx1.htm" onclick='_addDynClicks("wbimage", 1556346165, 1003)' target="_blank" title="">
#        <img alt="" src="images/ztxwimg2.jpg"/>
#       </a>
#      </li>
#      <li>
#       <a href="http://news.cufe.edu.cn/ztxw1/xxgcsjjlzqhjs.htm" onclick='_addDynClicks("wbimage", 1556346165, 53483)' target="_blank" title="">
#        <img alt="" src="images/sjjlzqh.jpg"/>
#       </a>
#      </li>
#      <li>
#       <a href="http://news.cufe.edu.cn/ztxw1/dsxxjy.htm" onclick='_addDynClicks("wbimage", 1556346165, 53408)' target="_blank" title="">
#        <img alt="" src="images/2021022504.png"/>
#       </a>
#      </li>
#      <li>
#       <a href="http://news.cufe.edu.cn/ztxw1/zggcdzycjdxdqcdbdh.htm" onclick='_addDynClicks("wbimage", 1556346165, 53377)' target="_blank" title="">
#        <img alt="" src="images/7777777777777.jpg"/>
#       </a>
#      </li>
#      <li>
#       <a href="http://news.cufe.edu.cn/ztxw1/qmtjxczx.htm" onclick='_addDynClicks("wbimage", 1556346165, 53407)' target="_blank" title="">
#        <img alt="" src="images/01.jpg"/>
#       </a>
#      </li>
#      <li>
#       <a href="http://news.cufe.edu.cn/ztxw1/z_y_jxs.htm" onclick='_addDynClicks("wbimage", 1556346165, 53167)' target="_blank" title="">
#        <img alt="" src="images/WechatIMG1162.jpeg"/>
#       </a>
#      </li>
#     </ul>
#    </div>
#   </div>
#   <div class="foot">
#    <span class="backTop">
#     <img src="images/top.jpg"/>
#    </span>
#    <div class="container2">
#     <div class="address fl">
#      <script language="javascript" src="/system/resource/js/news/mp4video.js">
#      </script>
#      <p>
#       学院南路校区地址：北京市海淀区学院南路39号
#       <br/>
#       邮编：100081
#      </p>
#      <p>
#       沙河校区地址：北京市昌平区沙河高教园区
#       <br/>
#       邮编：102206
#      </p>
#     </div>
#     <div class="footlogo fl">
#      <div>
#       <a href="index.htm" onclick='_addDynClicks("wbimage", 1556346165, 1007)' title="">
#        <img alt="" src="images/icons/footlogo.png" style="margin-top:50px; margin-bottom:30px;"/>
#       </a>
#      </div>
#      <div style="color: rgb(255, 255, 255); line-height: 30px; font-size: 16px;">
#       <!-- 版权内容请在本组件"内容配置-版权"处填写 -->
#       <p>
#        版权所有： 中央财经大学 京ICP备
#        <a href="https://beian.miit.gov.cn/" style="color: rgb(255, 255, 255);">
#         05004636号
#        </a>
#        <br/>
#        京公网安备110402430071号
#       </p>
#      </div>
#     </div>
#     <div class="copyright fr">
#      <ul class="share">
#       <li>
#        <a href="http://cufepaper.ihwrm.com/" onclick='_addDynClicks("wbimage", 1556346165, 53243)' target="_blank" title="">
#         <img alt="" src="images/xiaobaoicon.png" style="width:40px; height:40px"/>
#        </a>
#       </li>
#       <li class="code">
#        <a href="https://mp.weixin.qq.com/s/Fhe66cg0B5UJyVXOd5JkUw" onclick='_addDynClicks("wbimage", 1556346165, 53244)' target="_blank">
#         <img alt="" class="iconimg" src="images/icons/weixinicon.png" style="width:40px; height:40px"/>
#         <img alt="" class="codeimg" src="images/ewm.png"/>
#        </a>
#       </li>
#       <li>
#        <a href="https://m.weibo.cn/u/3113890133" onclick='_addDynClicks("wbimage", 1556346165, 53240)' target="_blank" title="微博">
#         <img alt="" src="images/icons/weiboicon.png" style="width:40px; height:40px"/>
#        </a>
#       </li>
#       <li class="code">
#        <img alt="" class="iconimg" src="images/20/04/09/2fvo1cb6za/kuaishouicon.png" style="width:40px; height:40px"/>
#        <img alt="" class="codeimg" src="images/kuaishou1.jpg"/>
#       </li>
#       <li class="code">
#        <img alt="" class="iconimg" src="images/20/04/09/2fvo1cb6za/douyinicon.png" style="width:40px; height:40px"/>
#        <img alt="" class="codeimg" src="images/douyin.jpg"/>
#       </li>
#       <li class="code">
#        <img alt="" class="iconimg" src="images/20/04/09/188uwv07lx/bilibiliicon.png" style="width:40px; height:40px"/>
#        <img alt="" class="codeimg" src="images/bilibili.jpg"/>
#       </li>
#       <li>
#        <a href="http://news.cufe.edu.cn/spsd.htm" onclick='_addDynClicks("wbimage", 1556346165, 53247)' target="_blank" title="">
#         <img alt="" src="images/20/04/09/188uwv07lx/shipinkongjianicon.png" style="width:40px; height:40px"/>
#        </a>
#       </li>
#       <li class="code">
#        <img alt="" class="iconimg" src="images/20/04/09/188uwv07lx/yangshipicon.png" style="width:40px; height:40px"/>
#        <img alt="" class="codeimg" src="images/yangshiping.png"/>
#       </li>
#      </ul>
#     </div>
#     <div class="clear">
#     </div>
#    </div>
#    <div class="foottj">
#     <div class="container">
#      <p>
#       <i>
#        <img alt="" height="12" src="images/icons/foottjicon.png" width="16"/>
#       </i>
#       <span>
#        <script language="javascript" src="_dwr/engine.js">
#        </script>
#        <script language="javascript" src="_dwr/util.js">
#        </script>
#        <script language="javascript" src="_dwr/interface/PageCounterDWR.js">
#        </script>
#        <span id="a246135" name="a246135">
#        </span>
#        <script>
#         function getvisittimea246135()
# {
#     PageCounterDWR.getVisittime('1556346165','1001','TOTAL_COUNTER','7895445','8',callbackdataa246135)
# }
# function callbackdataa246135(data)
# {
#     document.getElementById("a246135").innerHTML = data;
# }
# getvisittimea246135();
#        </script>
#       </span>
#      </p>
#     </div>
#    </div>
#   </div>
#   <script>
#    $('.hiSlider1').hiSlider({
#       isFlexible: true
# });
#   </script>
#   <script>
#    /* var swiper = new Swiper('.swiper-container', {
#             spaceBetween: 30,
#             centeredSlides: true,
#             loop: true,
#             autoplay: {
#                 delay: 2500,
#                 disableOnInteraction: false,
#             },
#             pagination: {
#                 el: '.swiper-pagination',
#                 clickable: true,
#             },
#             navigation: {
#                 nextEl: '.swiper-button-next',
#                 prevEl: '.swiper-button-prev',
#             },
#         });*/
#   </script>
#   <script>
#    $(".ggTab span").hover(function() {
#             $(this).addClass("on").siblings("span").removeClass("on");
#             var n = $(this).index();
#             $(".ggCon").eq(n).show().siblings(".ggCon").hide();
#         })
#   </script>
#   <script type="text/javascript">
#    $(function() {
#
#             $('#slick2').slick({
#                 infinite: true,
#                 slidesToShow: 1,
#                 slidesToScroll: 1,
#                 autoplay: true,
#                 centerMode: false,
#                 arrows: true,
#                 autoplaySpeed: 3000
#
#             });
#             $('#slick2').on('beforeChange', function(event, slick, currentSlide, nextSlide) {
#                 $(".timelist li").removeClass("active");
#                 $(".timelist li").eq(nextSlide).addClass("active");
#             });
#             $('#slcik2').on('setPosition', function(event, slick, currentSlide, nextSlide) {
#                 updateforw()
#             });
#             $(".timelist li").click(function() {
#                 $('#slick2').slick("slickGoTo", $(this).index());
#             });
#
#             $(".iconimg").hover(function(){
#                    $(this).next(".codeimg").fadeIn()
#                 },function(){
#                 $(this).next('.codeimg').fadeOut()
#                 })
#         })
#   </script>
#   <script type="text/javascript">
#    jQuery(".ui-header-nav").slide({
#             type: "menu",
#             titCell: "dd",
#             targetCell: "ul",
#             delayTime: 0,
#             defaultPlay: true,
#             returnDefault: true
#         });
#         $(window).bind("scroll", function() {
#
#             if ($(window).scrollTop() > 40) {
#                 if (!$(".nav").is(".scroll")) $(".nav").addClass("scroll");
#             } else {
#                 $(".nav").removeClass("scroll");
#             }
#         })
#   </script>
#   <script>
#    var srTarget;
#         $(".serbtn").click(function(e) {
#             srTarget = e.target;
#             $(".serbox").slideDown();
#         })
#         $(".serbox").click(function(e) {
#             srTarget = e.target;
#         })
#         $("html").click(function(event) {
#             if (event.target != srTarget) {
#                 $(".serbox").fadeOut();
#             }
#         });
#   </script>
#   <script type="text/javascript">
#    $(function() {
#             $(".line").slideUp();
#         })
#   </script>
#   <script>
#    $(function() {
#             //当滚动条的位置处于距顶部100像素以下时，跳转链接出现，否则消失
#             $(function() {
#                 $(window).scroll(function() {
#                     if ($(window).scrollTop() > 100) {
#                         $(".backTop").fadeIn(1500);
#                     } else {
#                         $(".backTop").fadeOut(1500);
#                     }
#                 });
#
#                 //当点击跳转链接后，回到页面顶部位置
#                 $(".backTop").click(function() {
#                     //$('body,html').animate({scrollTop:0},1000);
#                     if ($('html').scrollTop()) {
#                         $('html').animate({
#                             scrollTop: 0
#                         }, 1000);
#                         return false;
#                     }
#                     $('body').animate({
#                         scrollTop: 0
#                     }, 1000);
#                     return false;
#                 });
#             });
#         });
#   </script>
#  </body>
# </html>

# %% [markdown]
# # 3 动态网页爬虫

# %% [markdown]
# ## 3.1 环境搭建及配置
#
# ### 关于 Selenium
#
# - selenium 是一个 web 的自动化测试工具
#
# - 官方文档：https://selenium-python.readthedocs.io/index.html
#
# ### 安装驱动
#
# #### 前提条件
#
# - 已安装好Python开发环境（推荐安装Python3.5及以上版本）
#
# #### 安装步骤
#
# - 安装selenium<br>
#     Win：pip install selenium<br>
#     Mac:pip3 install selenium
#
#
# - 安装webdriver<br>
#     各大浏览器webdriver地址可参见：https://docs.seleniumhq.org/download/<br>
#     Firefox：https://github.com/mozilla/geckodriver/releases<br>
#     Chrome：http://npm.taobao.org/mirrors/chromedriver/<br>
# > 注：webdriver需要和对应的浏览器版本以及selenium版本对应
#
# windows 放在
# \Users\lenovo\AppData\Local\Google\Chrome\Application
# mac 放在
# /usr/local/bin

# %% [markdown]
# ## 3.2 元素定位及浏览器基本操作
#
# ### 3.2.1 启动浏览器
#
# #### 3.2.1.1 普通方式启动

# %%
#导入爬虫所需要的包
from selenium import webdriver
from selenium.webdriver.chrome.service import Service

import os 
import time
import requests
from bs4 import BeautifulSoup as bs

#不显示警示信息(不影响程序运行, 也可注释掉这两句)
import warnings
warnings.filterwarnings("ignore")

#输入网址, 获取信息
browser = webdriver.Chrome()
browser.get('http://www.sogou.com/')

# %%
browser.find_element(by = 'xpath', value = '//*[@id="query"]').send_keys("彭俞超")

browser.find_element(by = 'xpath', value = '//*[@id="stb"]').click()

time.sleep(1)

res = browser.page_source
#print(res.text)
soup = bs(res, 'lxml')
numbers= soup.find('p', {'class': 'num-tips'}).get_text().strip()
print(numbers)

#browser.quit()
# Out:
# 搜狗已为您找到约2,770条相关结果

# %% [markdown]
# #### 3.2.1.2 Headless方式启动
#
# - Headless Chrome 是 Chrome 浏览器的无界面形态，可以在不打开浏览器的前提下，使用所有 Chrome 支持的特性运行你的程序。相比于现代浏览器，Headless Chrome 更加方便测试 web 应用，获得网站的截图，做爬虫抓取信息等。相比于较早的 PhantomJS，SlimerJS 等，Headless Chrome 则更加贴近浏览器环境。

# %% [markdown]
# ### 3.2.2 元素定位
# - 对象的定位应该是自动化测试的核心，要想操作一个对象，首先应该识别这个对象。一个对象就是一个人一样，他会有各种的特征（属性），如比我们可以通过一个人的身份证号，姓名，或者他住在哪个街道、楼层、门牌找到这个人。那么一个对象也有类似的属性，我们可以通过这个属性找到这对象。
#
#
# - webdriver 提供了一系列的对象定位方法，常用的有以下几种：
#
#     id定位：find_element_by_id()<br>
#     name定位：find_element_by_name()<br>
#     class定位：find_element_by_class_name()<br>
#     link定位：find_element_by_link_text()<br>
#     partial link定位：find_element_by_partial_link_text()<br>
#     tag定位：find_element_by_tag_name()<br>
#     xpath定位：find_element_by_xpath()<br>
#     css定位：find_element_by_css_selector()

# %%
from selenium import webdriver

browser.get("http://www.sogou.com")

#Chrome——打开搜狗——右键检查——点按小箭头——放在搜狗搜索输入框

# 通过id方式定位
browser.find_element_by_id("query").send_keys("selenium")

# 通过name方式定位
browser.find_element_by_name("query").send_keys("selenium")

# 通过tag name方式定位
browser.find_element_by_tag_name("input")

# 通过class name方式定位
browser.find_element_by_class_name("sec-input").send_keys("selenium")

# 通过CSS方式定位
browser.find_element_by_css_selector("#query").send_keys("selenium")

# 通过xpath方式定位
browser.find_element_by_xpath('//*[@id="query"]').send_keys("selenium")

# 点击搜索
browser.find_element_by_id("stb").click()

browser.quit()

# %%
# 爬取信息详见实例3——央行网站
